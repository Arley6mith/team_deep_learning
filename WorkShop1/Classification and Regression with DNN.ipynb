# %% [markdown]
# # Classification and Regression using Deep Learning on tabular data

# %% [markdown]
# In this notebook, we'll go through the coding companion for Regression to create your very first neural network to predict whether the house price is below or above median value. We will go through the following in this notebook:
#
# - Exploring and Processing the Data
# - Building and Training our Neural Network
# - Visualizing Loss and Accuracy
# - Adding Regularization to our Neural Network
#
# The code is ready to run using house price data. Note that the results might differ because a degree of randomness in the way we split our dataset as well as the initialization of our neural network.
#
# This notebook is based on the work of Joseph Lee Wei En, 2019 at medium.com

# %% [markdown]
# # Exploring and Processing the Data

# %% [markdown]
# We first have to read in the CSV file that we've been given. We'll use a package called pandas for that:

# %%
#%pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -------------- ------------------------- 4.2/11.6 MB 22.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 23.4 MB/s eta 0:00:00
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('housepricedata.csv', sep = ',', encoding = 'utf-8') #wherever resides your data, if .ipnb and .csv are in the same folder no need to worry!
df.head(6)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
# 5    14115            5            5          796         1         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1
# 5             1             5           0         480                 0

# %%
#print(len(df. columns))
#len(df)
df.shape
# Out:
# (1460, 11)

# %% [markdown]
# The dataset that we have now is in what is called a pandas dataframe. To convert it to an array, simply access its values:

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]])

# %% [markdown]
# Now, we choose our input features and the Target we wish to predict.

# %%
X = dataset[:,0:10]
Y = dataset[:,10]

# %% [markdown]
# Normalizing our data is very important, as we want the input features to be on the same order of magnitude to make our training easier. We'll use a min-max scaler from scikit-learn which scales our data to be between 0 and 1.

# %%
#%pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (1.5.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.19.5 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from scikit-learn) (3.5.0)

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale  # Objective, target or output variable should not be scaled
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %% [markdown]
# Lastly, we wish to set aside some parts of our dataset for a validation set and a test set. We use the function train_test_split from scikit-learn to do that.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.1)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1314, 10) (73, 10) (73, 10) (1314,) (73,) (73,)

# %% [markdown]
# # Building and Training Our First Neural Network for "Classification"

# %%
#%pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (24.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 24.8 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.2
#     Uninstalling pip-24.2:
#       Successfully uninstalled pip-24.2
# Successfully installed pip-24.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install -U tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow)
#   Downloading tensorflow_intel-2.18.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Collecting wrapt>=1.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading wrapt-1.16.0-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading grpcio-1.67.1-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<2.1.0,>=1.26.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading numpy-2.0.2-cp310-cp310-win_amd64.whl.metadata (59 kB)
# Collecting h5py>=3.11.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading ml_dtypes-0.4.1-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Collecting rich (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading optree-0.13.0-cp310-cp310-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Collecting markdown>=2.6.8 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.18.0-cp310-cp310-win_amd64.whl (7.5 kB)
# Downloading tensorflow_intel-2.18.0-cp310-cp310-win_amd64.whl (390.0 MB)
#    ---------------------------------------- 0.0/390.0 MB ? eta -:--:--
#    ---------------------------------------- 2.1/390.0 MB 9.8 MB/s eta 0:00:40
#    ---------------------------------------- 4.2/390.0 MB 10.5 MB/s eta 0:00:37
#     --------------------------------------- 6.8/390.0 MB 10.8 MB/s eta 0:00:36
#     --------------------------------------- 9.4/390.0 MB 11.3 MB/s eta 0:00:34
#    - -------------------------------------- 12.3/390.0 MB 11.7 MB/s eta 0:00:33
#    - -------------------------------------- 16.0/390.0 MB 12.6 MB/s eta 0:00:30
#    -- ------------------------------------- 19.7/390.0 MB 13.4 MB/s eta 0:00:28
#    -- ------------------------------------- 23.6/390.0 MB 14.1 MB/s eta 0:00:27
#    -- ------------------------------------- 28.0/390.0 MB 14.8 MB/s eta 0:00:25
#    --- ------------------------------------ 32.2/390.0 MB 15.3 MB/s eta 0:00:24
#    --- ------------------------------------ 35.9/390.0 MB 15.4 MB/s eta 0:00:23
#    ---- ----------------------------------- 39.8/390.0 MB 15.8 MB/s eta 0:00:23
#    ---- ----------------------------------- 43.8/390.0 MB 16.1 MB/s eta 0:00:22
#    ---- ----------------------------------- 48.2/390.0 MB 16.3 MB/s eta 0:00:21
#    ----- ---------------------------------- 52.2/390.0 MB 16.5 MB/s eta 0:00:21
#    ----- ----------------------------------
#    ------------------------ -------------- 246.4/390.0 MB 19.5 MB/s eta 0:00:08
#    ------------------------- ------------- 251.9/390.0 MB 19.6 MB/s eta 0:00:08
#    ------------------------- ------------- 257.4/390.0 MB 19.7 MB/s eta 0:00:07
#    -------------------------- ------------ 262.4/390.0 MB 19.8 MB/s eta 0:00:07
#    -------------------------- ------------ 267.4/390.0 MB 20.2 MB/s eta 0:00:07
#    --------------------------- ----------- 272.1/390.0 MB 20.4 MB/s eta 0:00:06
#    --------------------------- ----------- 277.3/390.0 MB 20.7 MB/s eta 0:00:06
#    ---------------------------- ---------- 283.1/390.0 MB 20.8 MB/s eta 0:00:06
#    ---------------------------- ---------- 289.1/390.0 MB 21.0 MB/s eta 0:00:05
#    ----------------------------- --------- 294.4/390.0 MB 21.1 MB/s eta 0:00:05
#    ----------------------------- --------- 298.3/390.0 MB 21.2 MB/s eta 0:00:05
#    ------------------------------ -------- 304.3/390.0 MB 21.3 MB/s eta 0:00:05
#    ------------------------------ -------- 309.9/390.0 MB 21.4 MB/s eta 0:00:04
#    ------------------------------- ------- 315.4/390.0 MB 21.5 MB/s eta 0:00:04
#    -------------------------------- ------ 320.3/390.0 MB 21.6 MB/s eta 0:00:04
#    -------------------------------- ------ 324.3/390.0 MB 21.6 MB/s eta 0:00:04
#    -------------------------------- ------ 328.7/390.0 MB 22.0 MB/s eta 0:00:03
#    --------------------------------- ----- 334.0/390.0 MB 22.1 MB/s eta 0:00:03
#    --------------------------------- ----- 339.2/390.0 MB 22.2 MB/s eta 0:00:03
#    ---------------------------------- ---- 344.2/390.0 MB 22.7 MB/s eta 0:00:03
#    ---------------------------------- ---- 349.4/390.0 MB 22.7 MB/s eta 0:00:02
#    ----------------------------------- --- 354.4/390.0 MB 22.8 MB/s eta 0:00:02
#    ----------------------------------- --- 359.7/390.0 MB 22.8 MB/s eta 0:00:02
#    ------------------------------------ -- 365.2/390.0 MB 22.9 MB/s eta 0:00:02
#    ------------------------------------- - 370.4/390.0 MB 23.0 MB/s eta 0:00:01
#    ------------------------------------- - 375.7/390.0 MB 23.0 MB/s eta 0:00:01
#    --------------------------------------  381.2/390.0 MB 23.2 MB/s eta 0:00:01
#    --------------------------------------  386.7/390.0 MB 23.3 MB/s eta 0:00:01
#    --------------------------------------  389.8/390.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  389.8/390.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  389.8/390.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  389.8/390.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------  389.8/390.0 MB 23.4 MB/s eta 0:00:01
#    --------------------------------------- 390.0/390.0 MB 21.4 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.67.1-cp310-cp310-win_amd64.whl (4.4 MB)
#    ---------------------------------------- 0.0/4.4 MB ? eta -:--:--
#    -------------------------------------- - 4.2/4.4 MB 28.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.4/4.4 MB 17.5 MB/s eta 0:00:00
# Downloading h5py-3.12.1-cp310-cp310-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---------------------------------------- 3.0/3.0 MB 14.5 MB/s eta 0:00:00
# Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 19.8 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ------- -------------------------------- 5.2/26.4 MB 24.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 10.7/26.4 MB 24.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 15.7/26.4 MB 24.7 MB/s eta 0:00:01
#    ------------------------------- -------- 20.7/26.4 MB 24.7 MB/s eta 0:00:01
#    -------------------------------------- - 25.7/26.4 MB 24.6 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 21.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp310-cp310-win_amd64.whl (126 kB)
# Downloading numpy-2.0.2-cp310-cp310-win_amd64.whl (15.9 MB)
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    ------------- -------------------------- 5.5/15.9 MB 25.7 MB/s eta 0:00:01
#    -------------------------- ------------- 10.5/15.9 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------  15.7/15.9 MB 25.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.9/15.9 MB 22.2 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl (431 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ------------------------------------ --- 5.0/5.5 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 16.8 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 19.4 MB/s eta 0:00:00
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading wrapt-1.16.0-cp310-cp310-win_amd64.whl (37 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.13.0-cp310-cp310-win_amd64.whl (274 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, protobuf, optree, opt-einsum, numpy, mdurl, markdown, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, ml-dtypes, markdown-it-py, h5py, rich, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 grpcio-1.67.1 h5py-3.12.1 keras-3.6.0 libclang-18.1.1 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 ml-dtypes-0.4.1 namex-0.0.8 numpy-2.0.2 opt-einsum-3.4.0 optree-0.13.0 protobuf-5.28.3 rich-13.9.4 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 tensorflow-intel-2.18.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.5.0 werkzeug-3.1.3 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ASUS\miniconda3\envs\env_deep\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ASUS\miniconda3\envs\env_deep\Lib\site-packages\~umpy'.
#   You can safely remove it manually.

# %% [markdown]
# We will be using Keras to build our architecture. Let's import the code from Keras that we will need to use:

# %%
#%pip install protobuf==3.20.*
# Out:
# Collecting protobuf==3.20.*
#   Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl.metadata (698 bytes)
# Downloading protobuf-3.20.3-cp310-cp310-win_amd64.whl (904 kB)
#    ---------------------------------------- 0.0/904.0 kB ? eta -:--:--
#    --------------------------------------- 904.0/904.0 kB 13.7 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.28.3
#     Uninstalling protobuf-5.28.3:
#       Successfully uninstalled protobuf-5.28.3
# Successfully installed protobuf-3.20.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# We will be using the Sequential model, which means that we merely need to describe the layers above in sequence. Our neural network has three layers:
#
# - Hidden layer 1: 32 neurons, ReLU activation
# - Hidden layer 2: 32 neurons, ReLU activation
# - Output Layer: 1 neuron, Sigmoid activation

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])
# Out:
# c:\Users\ASUS\miniconda3\envs\env_deep\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Now that we've got our architecture specified, we need to find the best numbers for it. Before we start our training, we have to configure the model by
# - Telling it what algorithm you want to use to do the optimization (we'll use stochastic gradient descent)
# - Telling it what loss function to use (for binary classification, we will use binary cross entropy)
# - Telling it what other metrics you want to track apart from the loss function (we want to track accuracy as well)
#
# We do so below:

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Training on the data is pretty straightforward and requires us to write one line of code. The function is called 'fit' as we are fitting the parameters to the data. We specify:
# - what data we are training on, which is X_train and Y_train
# - the size of our mini-batch
# - how long we want to train it for (epochs)
# - what our validation data is so that the model will tell us how we are doing on the validation data at each point.
#
# This function will output a history, which we save under the variable hist. We'll use this variable a little later.

# %%
# batch size : of 1314 samples 32 samples will be taken at a
# time normally pairs

hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5077 - loss: 0.6843 - val_accuracy: 0.6164 - val_loss: 0.6713
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6115 - loss: 0.6748 - val_accuracy: 0.6575 - val_loss: 0.6626
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6526 - loss: 0.6658 - val_accuracy: 0.6301 - val_loss: 0.6531
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6806 - loss: 0.6529 - val_accuracy: 0.6438 - val_loss: 0.6447
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6861 - loss: 0.6497 - val_accuracy: 0.6575 - val_loss: 0.6363
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7298 - loss: 0.6325 - val_accuracy: 0.6712 - val_loss: 0.6282
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7192 - loss: 0.6276 - val_accuracy: 0.7260 - val_loss: 0.6207
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7424 - loss: 0.6262 - val_accuracy: 0.7123 - val_loss: 0.6121
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7301 - loss: 0.6189 - val_accuracy: 0.7671 - val_loss: 0.6041
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7785 - loss: 0.6032 - val_accuracy: 0.7671 - val_loss: 0.5953
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7507 - loss: 0.5968 - val_accuracy: 0.7671 - val_loss: 0.5866
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7677 - loss: 0.5902 - val_accuracy: 0.7671 - val_loss: 0.5786
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7896 - loss: 0.5744 - val_accuracy: 0.7671 - val_loss: 0.5683
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7777 - loss: 0.5700 - val_accuracy: 0.8082 - val_loss: 0.5589
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7815 - loss: 0.5647 - val_accuracy: 0.8082 - val_loss: 0.5489
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8066 - loss: 0.5475 - val_accuracy: 0.8219 - val_loss: 0.5384
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8107 - loss: 0.5384 - val_accuracy: 0.8082 - val_loss: 0.5295
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8127 - loss: 0.5331 - val_accuracy: 0.8356 - val_loss: 0.5190
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8279 - loss: 0.5134 - val_accuracy: 0.8356 - val_loss: 0.5084
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8490 - loss: 0.4966 - val_accuracy: 0.8219 - val_loss: 0.4985
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8107 - loss: 0.5016 - val_accuracy: 0.8219 - val_loss: 0.4882
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8361 - loss: 0.4741 - val_accuracy: 0.8082 - val_loss: 0.4820
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8194 - loss: 0.4803 - val_accuracy: 0.8356 - val_loss: 0.4695
# Epoch 24/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8400 - loss: 0.4635 - val_accuracy: 0.8493 - val_loss: 0.4598
# Epoch 25/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8514 - loss: 0.4480 - val_accuracy: 0.8219 - val_loss: 0.4510
# Epoch 26/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8418 - loss: 0.4490 - val_accuracy: 0.8493 - val_loss: 0.4420
# Epoch 27/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8443 - loss: 0.4354 - val_accuracy: 0.8356 - val_loss: 0.4354
# Epoch 28/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8591 - loss: 0.4304 - val_accuracy: 0.8493 - val_loss: 0.4266
# Epoch 29/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8584 - loss: 0.4256 - val_accuracy: 0.8493 - val_loss: 0.4201
# Epoch 30/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.4249 - val_accuracy: 0.8493 - val_loss: 0.4128
# Epoch 31/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8710 - loss: 0.4015 - val_accuracy: 0.8082 - val_loss: 0.4057
# Epoch 32/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8686 - loss: 0.3923 - val_accuracy: 0.8219 - val_loss: 0.4004
# Epoch 33/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8564 - loss: 0
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8863 - loss: 0.2803 - val_accuracy: 0.8767 - val_loss: 0.2841
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8962 - loss: 0.2630 - val_accuracy: 0.8630 - val_loss: 0.2870
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8726 - loss: 0.2873 - val_accuracy: 0.8767 - val_loss: 0.2826
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8960 - loss: 0.2771 - val_accuracy: 0.8630 - val_loss: 0.2826
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.2695 - val_accuracy: 0.8630 - val_loss: 0.2824
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8986 - loss: 0.2603 - val_accuracy: 0.8630 - val_loss: 0.2807
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8818 - loss: 0.3058 - val_accuracy: 0.8767 - val_loss: 0.2771
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8973 - loss: 0.2788 - val_accuracy: 0.8767 - val_loss: 0.2845
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8966 - loss: 0.2849 - val_accuracy: 0.8767 - val_loss: 0.2811
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8832 - loss: 0.2753 - val_accuracy: 0.8767 - val_loss: 0.2737
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8942 - loss: 0.2927 - val_accuracy: 0.8767 - val_loss: 0.2772
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.2724 - val_accuracy: 0.8767 - val_loss: 0.2733
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8861 - loss: 0.3032 - val_accuracy: 0.8767 - val_loss: 0.2711
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.2623 - val_accuracy: 0.8904 - val_loss: 0.2723
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8908 - loss: 0.2779 - val_accuracy: 0.8767 - val_loss: 0.2684
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8940 - loss: 0.2599 - val_accuracy: 0.8767 - val_loss: 0.2678
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8979 - loss: 0.2691 - val_accuracy: 0.8767 - val_loss: 0.2664
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8843 - loss: 0.3038 - val_accuracy: 0.8904 - val_loss: 0.2667
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9004 - loss: 0.2621 - val_accuracy: 0.9041 - val_loss: 0.2708
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8829 - loss: 0.2952 - val_accuracy: 0.8904 - val_loss: 0.2937
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8843 - loss: 0.2648 - val_accuracy: 0.8904 - val_loss: 0.2626
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8789 - loss: 0.2790 - val_accuracy: 0.9041 - val_loss: 0.2656
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8842 - loss: 0.2732 - val_accuracy: 0.9041 - val_loss: 0.2668
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8962 - loss: 0.2570 - val_accuracy: 0.8767 - val_loss: 0.2584

# %% [markdown]
# Evaluating our model on the test set:

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8348 - loss: 0.3329
# 0.8493150472640991

# %% [markdown]
# # Visualizing Loss and Accuracy

# %% [markdown]
# Import the relevant package we need to do the visualization

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# We want to visualize the training loss and the validation loss like this:

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train_loss', 'Valid_loss'], loc='upper right')
plt.show()

# %% [markdown]
# We can also visualize the training accuracy and the validation accuracy like this:

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Valid'], loc='lower right')
plt.show()

# %% [markdown]
# # Adding Regularization to our Neural Network

# %% [markdown]
# We'll train a model which will overfit, which we call Model 2. This might take a few minutes.

# %%
model_2 = Sequential([
    Dense(1000, activation='relu', input_shape=(10,)),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1000, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# using adaptative moment estimation (adam)

model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_2 = model_2.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# c:\Users\ASUS\miniconda3\envs\env_deep\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7757 - loss: 0.4884 - val_accuracy: 0.7397 - val_loss: 0.5521
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8605 - loss: 0.3718 - val_accuracy: 0.8493 - val_loss: 0.2981
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8616 - loss: 0.3313 - val_accuracy: 0.9041 - val_loss: 0.2576
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8685 - loss: 0.3068 - val_accuracy: 0.9178 - val_loss: 0.2648
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8783 - loss: 0.2942 - val_accuracy: 0.9178 - val_loss: 0.1845
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9034 - loss: 0.2460 - val_accuracy: 0.8904 - val_loss: 0.2194
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9141 - loss: 0.2312 - val_accuracy: 0.9178 - val_loss: 0.1844
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8839 - loss: 0.2783 - val_accuracy: 0.9315 - val_loss: 0.1878
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9075 - loss: 0.2365 - val_accuracy: 0.9452 - val_loss: 0.1879
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8979 - loss: 0.2472 - val_accuracy: 0.9315 - val_loss: 0.1895
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9061 - loss: 0.2375 - val_accuracy: 0.9452 - val_loss: 0.1867
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9278 - loss: 0.1578 - val_accuracy: 0.9178 - val_loss: 0.1514
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9208 - loss: 0.1604 - val_accuracy: 0.9452 - val_loss: 0.2923
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9448 - loss: 0.1406 - val_accuracy: 0.9178 - val_loss: 0.2162
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9333 - loss: 0.1589 - val_accuracy: 0.9178 - val_loss: 0.1605
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9252 - loss: 0.1784 - val_accuracy: 0.9452 - val_loss: 0.2346
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9381 - loss: 0.1641 - val_accuracy: 0.9178 - val_loss: 0.1914
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9269 - loss: 0.1735 - val_accuracy: 0.9589 - val_loss: 0.1120
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9195 - loss: 0.1954 - val_accuracy: 0.9452 - val_loss: 0.1865
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9265 - loss: 0.1604 - val_accuracy: 0.9452 - val_loss: 0.1211
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9399 - loss: 0.1480 - val_accuracy: 0.9452 - val_loss: 0.2254
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9326 - loss: 0.1526 - val_accuracy: 0.9452 - val_loss: 0.2503

# %% [markdown]
# Let's do the same visualization to see what overfitting looks like in terms of the loss and accuracy.

# %%
plt.plot(hist_2.history['loss'])
plt.plot(hist_2.history['val_loss'])
plt.title('Loss for an overfitted model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(hist_2.history['accuracy'])
plt.plot(hist_2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# To address the overfitting we see in Model 2, we'll incorporate L2 regularization and dropout in our third model here (Model 3).

# %%
from keras.layers import Dropout
from keras import regularizers

# %%
# HINT WORKSHOP!: Use this doptout and 0.01 , and batch size between 32 and 100 for workshop
model_3 = Sequential([
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01), input_shape=(10,)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1000, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    Dropout(0.5),
    Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)),
])

# %%
a = 0.01
b = -0.01
c = 0.1
print(a*a)
print(b*b)
print(c*c)
# Out:
# 0.0001
# 0.0001
# 0.010000000000000002

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
hist_3 = model_3.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5365 - loss: 19.2994 - val_accuracy: 0.8356 - val_loss: 2.0714
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8045 - loss: 1.3363 - val_accuracy: 0.8767 - val_loss: 0.5527
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8464 - loss: 0.5707 - val_accuracy: 0.8767 - val_loss: 0.5290
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8520 - loss: 0.5494 - val_accuracy: 0.8219 - val_loss: 0.5635
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8400 - loss: 0.5307 - val_accuracy: 0.8767 - val_loss: 0.4645
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8756 - loss: 0.4920 - val_accuracy: 0.9041 - val_loss: 0.4719
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8774 - loss: 0.4872 - val_accuracy: 0.8630 - val_loss: 0.5040
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8535 - loss: 0.5375 - val_accuracy: 0.9041 - val_loss: 0.4541
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8573 - loss: 0.5043 - val_accuracy: 0.9041 - val_loss: 0.4342
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8773 - loss: 0.5011 - val_accuracy: 0.8904 - val_loss: 0.4530
# Epoch 11/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8596 - loss: 0.5077 - val_accuracy: 0.9041 - val_loss: 0.4311
# Epoch 12/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8680 - loss: 0.4919 - val_accuracy: 0.9041 - val_loss: 0.4247
# Epoch 13/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8648 - loss: 0.4952 - val_accuracy: 0.9041 - val_loss: 0.4332
# Epoch 14/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8847 - loss: 0.4535 - val_accuracy: 0.9041 - val_loss: 0.4455
# Epoch 15/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8387 - loss: 0.5613 - val_accuracy: 0.9041 - val_loss: 0.4237
# Epoch 16/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8653 - loss: 0.4864 - val_accuracy: 0.9041 - val_loss: 0.4161
# Epoch 17/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8703 - loss: 0.4751 - val_accuracy: 0.9041 - val_loss: 0.4252
# Epoch 18/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8640 - loss: 0.4780 - val_accuracy: 0.9041 - val_loss: 0.4300
# Epoch 19/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8647 - loss: 0.4732 - val_accuracy: 0.9041 - val_loss: 0.4026
# Epoch 20/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8813 - loss: 0.4703 - val_accuracy: 0.9178 - val_loss: 0.4002
# Epoch 21/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8586 - loss: 0.5004 - val_accuracy: 0.9041 - val_loss: 0.4329
# Epoch 22/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8734 - loss: 0.4808 - val_accuracy: 0.9041 - val_loss: 0.4367
# Epoch 23/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.
# Epoch 73/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8760 - loss: 0.4793 - val_accuracy: 0.9178 - val_loss: 0.4006
# Epoch 74/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8600 - loss: 0.5046 - val_accuracy: 0.9041 - val_loss: 0.4015
# Epoch 75/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8747 - loss: 0.4937 - val_accuracy: 0.9041 - val_loss: 0.4046
# Epoch 76/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8766 - loss: 0.4538 - val_accuracy: 0.9178 - val_loss: 0.3924
# Epoch 77/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8630 - loss: 0.4734 - val_accuracy: 0.9178 - val_loss: 0.3808
# Epoch 78/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8804 - loss: 0.4552 - val_accuracy: 0.9178 - val_loss: 0.3840
# Epoch 79/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8798 - loss: 0.4638 - val_accuracy: 0.9041 - val_loss: 0.4124
# Epoch 80/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8827 - loss: 0.4473 - val_accuracy: 0.9178 - val_loss: 0.3924
# Epoch 81/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8815 - loss: 0.4530 - val_accuracy: 0.9041 - val_loss: 0.3995
# Epoch 82/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8592 - loss: 0.4818 - val_accuracy: 0.9178 - val_loss: 0.3967
# Epoch 83/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8866 - loss: 0.4555 - val_accuracy: 0.9178 - val_loss: 0.3809
# Epoch 84/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8786 - loss: 0.4631 - val_accuracy: 0.9041 - val_loss: 0.4021
# Epoch 85/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8737 - loss: 0.4486 - val_accuracy: 0.9178 - val_loss: 0.3816
# Epoch 86/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8933 - loss: 0.4402 - val_accuracy: 0.8904 - val_loss: 0.4090
# Epoch 87/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8751 - loss: 0.4536 - val_accuracy: 0.9178 - val_loss: 0.3919
# Epoch 88/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8745 - loss: 0.4541 - val_accuracy: 0.9041 - val_loss: 0.3885
# Epoch 89/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8653 - loss: 0.4672 - val_accuracy: 0.9178 - val_loss: 0.3760
# Epoch 90/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8841 - loss: 0.4760 - val_accuracy: 0.9041 - val_loss: 0.4174
# Epoch 91/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8856 - loss: 0.4637 - val_accuracy: 0.8767 - val_loss: 0.4683
# Epoch 92/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8649 - loss: 0.5096 - val_accuracy: 0.9041 - val_loss: 0.3984
# Epoch 93/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8708 - loss: 0.4880 - val_accuracy: 0.9041 - val_loss: 0.4229
# Epoch 94/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8645 - loss: 0.4997 - val_accuracy: 0.9041 - val_loss: 0.3945
# Epoch 95/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8790 - loss: 0.4652 - val_accuracy: 0.9315 - val_loss: 0.3845
# Epoch 96/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8816 - loss: 0.4560 - val_accuracy: 0.9041 - val_loss: 0.4041
# Epoch 97/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8852 - loss: 0.4576 - val_accuracy: 0.9178 - val_loss: 0.3819
# Epoch 98/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.8818 - loss: 0.4525 - val_accuracy: 0.9041 - val_loss: 0.3757
# Epoch 99/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.8710 - loss: 0.4801 - val_accuracy: 0.9041 - val_loss: 0.3884
# Epoch 100/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8780 - loss: 0.4656 - val_accuracy: 0.9041 - val_loss: 0.3786

# %%
plt.plot(hist_3v2.history['loss'])
plt.plot(hist_3v2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.ylim(top=1.2, bottom=0)
plt.show()

# %%
plt.plot(hist_3v2.history['accuracy'])
plt.plot(hist_3v2.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %% [markdown]
# What do you think? you decide which dp is better !

# %% [markdown]
# # Regression (Finding a value)

# %% [markdown]
# Which features are available in the dataset?
#
# Which features are categorical?
#
# Which features are numerical?
#
# Which features contain blank, null or empty values?
#
# What are the data types for various features?
#
# What is the distribution of numerical feature values across the samples?
#
# Which features are more correlated to the price?

# %% [markdown]
# Dataset
# This dataset contains house sale prices for King County, which includes Seattle.
# It includes homes sold between May 2014 and May 2015.
# 21 columns. (features)
# 21597 rows.
# Feature Columns
#
# id: Unique ID for each home sold
#
# date: Date of the home sale
#
# price: Price of each home sold
#
# bedrooms: Number of bedrooms
#
# bathrooms: Number of bathrooms, where .5 accounts for a room with a toilet but no shower
#
# sqft_living: Square footage of the apartments interior living space
#
# sqft_lot: Square footage of the land space
#
# floors: Number of floors
#
# waterfront: - A dummy variable for whether the apartment was overlooking the waterfront or not
#
# view: An index from 0 to 4 of how good the view of the property was
#
# condition: - An index from 1 to 5 on the condition of the apartment,
#
# grade: An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
#
# sqft_above: The square footage of the interior housing space that is above ground level
#
# sqft_basement: The square footage of the interior housing space that is below ground level
#
# yr_built: The year the house was initially built
#
# yr_renovated: The year of the house’s last renovation
#
# zipcode: What zipcode area the house is in
#
# lat: Lattitude
#
# long: Longitude
#
# sqft_living15: The square footage of interior housing living space for the nearest 15 neighbors
#
# sqft_lot15: The square footage of the land lots of the nearest 15 neighbors

# %%
# data analysis
import pandas as pd
import numpy as np

# models
from keras import layers
from keras import preprocessing
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam   # if keras does not find it

# preprocessing
from sklearn import preprocessing

# Split
from sklearn.model_selection import train_test_split

# %%
# %pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
housePrices=pd.read_excel('kc_house_data_yr.xlsx')
print(len(housePrices))

# preview the data desde la cabeza
housePrices.head()
# Out:
# 21613
#            id      date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900         3       1.00         1180      5650
# 1  6414100192  20141209  538000         3       2.25         2570      7242
# 2  5631500400  20150225  180000         2       1.00          770     10000
# 3  2487200875  20141209  604000         4       3.00         1960      5000
# 4  1954400510  20150218  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0             0    98178  47.5112 -122.257           1340        5650
# 1          1991    98125  47.7210 -122.319           1690        7639
# 2             0    98028  47.7379 -122.233           2720        8062
# 3             0    98136  47.5208 -122.393           1360        5000
# 4             0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
housePrices.tail()  # previewing the data from the backwards, this is from the tail !
# Out:
#                id      date   price  bedrooms  bathrooms  sqft_living  \
# 21608   263000018  20140521  360000         3       2.50         1530
# 21609  6600060120  20150223  400000         4       2.50         2310
# 21610  1523300141  20140623  402101         2       0.75         1020
# 21611   291310100  20150116  400000         3       2.50         1600
# 21612  1523300157  20141015  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21608      1131     3.0           0     0  ...      8        1530
# 21609      5813     2.0           0     0  ...      8        2310
# 21610      1350     2.0           0     0  ...      7        1020
# 21611      2388     2.0           0     0  ...      8        1600
# 21612      1076     2.0           0     0  ...      7        1020
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 21608              0      2009             0    98103  47.6993 -122.346
# 21609              0      2014             0    98146  47.5107 -122.362
# 21610              0      2009             0    98144  47.5944 -122.299
# 21611              0      2004             0    98027  47.5345 -122.069
# 21612              0      2008             0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 21608           1530        1509
# 21609           1830        7200
# 21610           1020        2007
# 21611           1410        1287
# 21612           1020        1357
#
# [5 rows x 21 columns]

# %%
housePrices.shape
# Out:
# (21613, 21)

# %%
len(housePrices.columns)
# Out:
# 21

# %%
housePrices.dtypes   # Investigation data types is always good !  object type are strings**
# Out:
# id                 int64
# date               int64
# price              int64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  int64
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(17)
# memory usage: 3.5 MB

# %% [markdown]
# Which features contain blank, null or empty values?
#
# We can check for missing values with pandas isnull(). This indicates whether values are missing or not. Then we can sum all the values to check every column.

# %%
# Number of null values per feature
housePrices.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# What is the distribution of numerical feature values across the samples?

# %%
housePrices.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# date           21613.0  2.014390e+07  4.436582e+03  2.014050e+07
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# yr_built       21613.0  1.971005e+03  2.937341e+01  1.900000e+03
# yr_renovated   21613.0  8.440226e+01  4.016792e+02  0.000000e+00
# zipcode        21613.0  9.807794e+04  5.350503e+01  9.800100e+04
# lat            21613.0  4.756005e+01  1.385637e-01  4.715590e+01
# long           21613.0 -1.222139e+02  1.408283e-01 -1.225190e+02
# sqft_living15  21613.0  1.986552e+03  6.853913e+02  3.990000e+02
# sqft_lot15     21613.0  1.276846e+04  2.730418e+04  6.510000e+02
#
#                         25%           50%           75%           max
# id             2.123049e+09  3.904930e+09  7.308900e+09  9.900000e+09
# date           2.014072e+07  2.014102e+07  2.015022e+07  2.015053e+07
# price          3.219500e+05  4.500000e+05  6.450000e+05  7.700000e+06
# bedrooms       3.000000e+00  3.000000e+00  4.000000e+00  3.300000e+01
# bathrooms      1.750000e+00  2.250000e+00  2.500000e+00  8.000000e+00
# sqft_living    1.427000e+03  1.910000e+03  2.550000e+03  1.354000e+04
# sqft_lot       5.040000e+03  7.618000e+03  1.068800e+04  1.651359e+06
# floors         1.000000e+00  1.500000e+00  2.000000e+00  3.500000e+00
# waterfront     0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# view           0.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# condition      3.000000e+00  3.000000e+00  4.000000e+00  5.000000e+00
# grade          7.000000e+00  7.000000e+00  8.000000e+00  1.300000e+01
# sqft_above     1.190000e+03  1.560000e+03  2.210000e+03  9.410000e+03
# sqft_basement  0.000000e+00  0.000000e+00  5.600000e+02  4.820000e+03
# yr_built       1.951000e+03  1.975000e+03  1.997000e+03  2.015000e+03
# yr_renovated   0.000000e+00  0.000000e+00  0.000000e+00  2.015000e+03
# zipcode        9.803300e+04  9.806500e+04  9.811800e+04  9.819900e+04
# lat            4.747100e+01  4.757180e+01  4.767800e+01  4.777760e+01
# long          -1.223280e+02 -1.222300e+02 -1.221250e+02 -1.213150e+02
# sqft_living15  1.490000e+03  1.840000e+03  2.360000e+03  6.210000e+03
# sqft_lot15     5.100000e+03  7.620000e+03  1.008300e+04  8.712000e+05

# %% [markdown]
# __Completing__
#
# Since there are no missing values we do not need to complete any values.

# %% [markdown]
# __Preparation__
#
# Id feature may be dropped from our analysis since it does not add value. Date feature may be dropped since we are going to do feature engineering and make a year and month column. Zipcode feature is a special case, we could use it, but since we do not know exactly the zones of King County we are just going to drop it. Treat strings as categories. Although Zip code is numeric, we cannot treat it as a number in the model, it may be converted to a string.

# %% [markdown]
# __Creating__
#
# We may want to create a new feature called Year based on Date to analyze the price change throughout the years. We may want to create a new feature called Month based on Date to analyze the price change throughout the months.

# %% [markdown]
# __Correlation__
#
# We want to know how well does each feature correlate with Price. We want to do this early in our project and match these quick correlations with modelled correlations later in the project.
#
# Analyze by visualizing data using the __Pearson correlation matrix__
#
# It plots a coefficient to examine the strength and direction of the linear relationship between two continuous variables.
#
# The correlation coefficient can range in value from −1 to +1. The larger the absolute value of the coefficient, the stronger the relationship between the variables. For the Pearson correlation, an absolute value of 1 indicates a perfect linear relationship. A correlation close to 0 indicates no linear relationship between the variables.
#
# The sign of the coefficient indicates the direction of the relationship. If both variables tend to increase or decrease together, the coefficient is positive, and the line that represents the correlation slopes upward. If one variable tends to increase as the other decreases, the coefficient is negative, and the line that represents the correlation slopes downward.

# %%
# %pip install seaborn
# Out:
# Collecting seabornNote: you may need to restart the kernel to use updated packages.
#
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\miniconda3\envs\env_deep\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(style='whitegrid', font_scale=1)

plt.figure(figsize=(13,13))
plt.title('Pearson Correlation Matrix',fontsize=25)
sns.heatmap(housePrices.corr(),linewidths=0.25,vmax=0.7,square=True,cmap='GnBu',linecolor='w',
            annot=True, annot_kws={'size':7}, cbar_kws={'shrink': .7})
# Out:
# <Axes: title={'center': 'Pearson Correlation Matrix'}>

# %% [markdown]
# Which features are more correlated to the price?
#
# This allow us to explore labels that are highly correlated to the price.
# sqft_living looks like a highly correlated label to the price, as well as grade, sqft_above, sqft_living15 and bathrooms.

# %%
price_corr = housePrices.corr()['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702035
# grade            0.667434
# sqft_above       0.605567
# sqft_living15    0.585379
# bathrooms        0.525138
# view             0.397293
# sqft_basement    0.323816
# bedrooms         0.308350
# lat              0.307003
# waterfront       0.266369
# floors           0.256794
# yr_renovated     0.126434
# sqft_lot         0.089661
# sqft_lot15       0.082447
# yr_built         0.054012
# condition        0.036362
# long             0.021626
# date             0.003033
# id              -0.016762
# zipcode         -0.053203
# Name: price, dtype: float64

# %% [markdown]
# __Price feature__
#
# Most of the house prices are between 0 and 1,500,000.
#
# The average house price is $540,000.
#
# Keep in mind that it may be a good idea to drop extreme values. For instance, we could focus on house from 0 to $3,000,000 and
# drop the other ones.
#
# It seems that there is a positive linear relationship between the price and sqft_living.
#
# An increase in living space generally corresponds to an increase in house price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.histplot(housePrices['price'], ax=axes[0])
sns.scatterplot(x='price',y='sqft_living', data=housePrices, ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Price in millions (USD)', ylabel='Frequency', title='Price Distribuition')
axes[1].set(xlabel='Price', ylabel='Sqft Living', title='Price vs Sqft Living')
axes[1].yaxis.set_label_position("right")
axes[1].yaxis.tick_right()

# %% [markdown]
# __Bedrooms and floors box plots__
#
# Box plot is a method for graphically depicting groups of numerical data through their quartiles. Box plots may also have lines extending from the boxes (whiskers) indicating variability outside the upper and lower quartiles, hence the terms box-and-whisker plot. Outliers may be plotted as individual points. The spacings between the different parts of the box indicate the degree of dispersion (spread).
#
# We can see outliers plotted as individual points; this probably are the more expensive houses.
# We can see that the price tends to go up when the house has more bedrooms.

# %%
sns.set(style="whitegrid", font_scale=1)

f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=housePrices['bedrooms'],y=housePrices['price'], ax=axes[0])
sns.boxplot(x=housePrices['floors'],y=housePrices['price'], ax=axes[1])
sns.despine(bottom=True, left=True)
axes[0].set(xlabel='Bedrooms', ylabel='Price', title='Bedrooms vs Price Box Plot')
axes[1].set(xlabel='Floors', ylabel='Price', title='Floors vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Floors'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Floors vs Price Box Plot')]

# %% [markdown]
# __Waterfront, view and grade box plots__
#
# Waterfront houses tends to have a better price value.
# The price of waterfront houses tends to be more disperse and the price of houses without waterfront tend to be more concentrated.
# Grade and waterfront effect price. View seem to effect less but it also has an effect on price.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x=housePrices['waterfront'],y=housePrices['price'], ax=axes[0])
sns.boxplot(x=housePrices['view'],y=housePrices['price'], ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Waterfront', ylabel='Price', title='Waterfront vs Price Box Plot')
axes[1].set(xlabel='View', ylabel='Price', title='View vs Price Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
sns.boxplot(x=housePrices['grade'],y=housePrices['price'], ax=axe)
sns.despine(left=True, bottom=True)
axe.set(xlabel='Grade', ylabel='Price', title='Grade vs Price Box Plot')
# Out:
# [Text(0.5, 0, 'Grade'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Grade vs Price Box Plot')]

# %%
[housePrices['view'].unique().tolist() for view in housePrices.columns]
# Out:
# [[0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1],
#  [0, 3, 4, 2, 1]]

# %% [markdown]
# __Working with Feature Data = Feature engineering__
#
# __Correcting by dropping features__
#
# By dropping features, we are dealing with fewer data points. Speeds up our notebook and eases the analysis. Based on our assumptions and decisions we want to drop the Id, zipcode and Date features.

# %%
housePrices = housePrices.drop('id',axis=1)
housePrices = housePrices.drop('zipcode',axis=1)
print(housePrices.columns.values)
# Out:
# ['date' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15']

# %% [markdown]
# We want to engineer the date feature to make a year and month column. The feature date is as a string. With pd.to_datetime we can convert an argument to datetime.

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  int64
#  1   price          21613 non-null  int64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(15)
# memory usage: 3.1 MB

# %%
housePrices['date'] = housePrices['date'].values.astype(str)

# %%
housePrices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  int64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
# dtypes: float64(4), int64(14), object(1)
# memory usage: 3.1+ MB

# %%
housePrices['date'] = pd.to_datetime(housePrices['date'])

housePrices['month'] = housePrices['date'].apply(lambda date:date.month)
housePrices['year'] = housePrices['date'].apply(lambda date:date.year)

housePrices = housePrices.drop('date',axis=1)

# Check the new columns
print(housePrices.columns.values)
# Out:
# ['price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot' 'floors'
#  'waterfront' 'view' 'condition' 'grade' 'sqft_above' 'sqft_basement'
#  'yr_built' 'yr_renovated' 'lat' 'long' 'sqft_living15' 'sqft_lot15'
#  'month' 'year']

# %%
print('now the dataframe looks like this:')
housePrices.head(5)
# Out:
# now the dataframe looks like this:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900         3       1.00         1180      5650     1.0           0
# 1  538000         3       2.25         2570      7242     2.0           0
# 2  180000         2       1.00          770     10000     1.0           0
# 3  604000         4       3.00         1960      5000     1.0           0
# 4  510000         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year
# 0  47.5112 -122.257           1340        5650     10  2014
# 1  47.7210 -122.319           1690        7639     12  2014
# 2  47.7379 -122.233           2720        8062      2  2015
# 3  47.5208 -122.393           1360        5000     12  2014
# 4  47.6168 -122.045           1800        7503      2  2015

# %% [markdown]
# __House price trends, Price vs month, vs year__
#
# Looking the box plots we notice that there is not a big difference between 2014 and 2015.
# The number of houses sold by month tends to be similar every month.
# The line plot show that around April there is an increase in house prices.

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
sns.boxplot(x='year',y='price',data=housePrices, ax=axes[0])
sns.boxplot(x='month',y='price',data=housePrices, ax=axes[1])
sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Year', ylabel='Price', title='Price by Year Box Plot')
axes[1].set(xlabel='Month', ylabel='Price', title='Price by Month Box Plot')

f, axe = plt.subplots(1, 1,figsize=(15,5))
housePrices.groupby('month').mean()['price'].plot()
sns.despine(left=True, bottom=True)
axe.set(xlabel='Month', ylabel='Price', title='Price Trends')
# Out:
# [Text(0.5, 0, 'Month'), Text(0, 0.5, 'Price'), Text(0.5, 1.0, 'Price Trends')]

# %% [markdown]
# __Splitting data into training, validation and testing sets__
#
# Instead of a class, Regression problems are measured by a `mean squared error or "MSE"`

# %% [markdown]
# Again, in supervised learning, we are training our model with a given dataset of examples f(X) = y, where X are a set of variables, y is the value to predict and f is the DNN !

# %%
# Features
X = housePrices.drop('price',axis=1)

# Label
y = housePrices['price']

# Split
X_train, X_valid, y_train, y_valid = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
print(X_train.shape)
print(X_valid.shape)
print(y_train.shape)
print(y_valid.shape)
# Out:
# (15129, 19)
# (6484, 19)
# (15129,)
# (6484,)

# %% [markdown]
# __Scaling Data__
#
# In Machine Learning, including Deep Learning, Gaussian distributions are the key, so adjusting data to gaussian is kean
# Even more, having a standard deviation of 1 and median of 0 is ideal.
#
# fit_transform(X[, y]): Fit to data, then transform it.
# transform(X): Scale features of X according to feature_range.

# %%
# scaling and train test split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()

# fit and transfrom
X_train = scaler.fit_transform(X_train)

# transform for avoiding data leakage
X_valid = scaler.transform(X_valid)

# everything has been scaled between 1 and 0
print('Max: ',X_train.max())
print('Min: ', X_train.min())
# Out:
# Max:  1.0000000000000002
# Min:  0.0

# %% [markdown]
# __Creating a model == The f, the DNN__
#
# We estimate the number of neurons (units) from our features. Ex: X_train.shape (15129, 19). The optimizer is asking how you want to perform this gradient descent. In this case we are using the Adam optimizer and the mean square error loss function.

# %%
model = Sequential()

# input layer
model.add(Dense(19,activation='relu'))

# hidden layers
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))

# output layer
model.add(Dense(1))  # This is the decision layer class or value depending on the need !

model.compile(optimizer='adam',loss='mse')

# %% [markdown]
# __Training the model, the f, the DNN__
#
# Now that the model, architecture, 'stomach' is ready, we can fit the model into the data.
#
# Since the dataset is large, we are going to use batch_size. It is typical to use batches of the power of 2 (32, 64, 128, 256...). In this case we are using 128. The smaller the batch size, the longer is going to take.

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_valid,y_valid.values),
          batch_size=128,epochs=400)
# Out:
# Epoch 1/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 415167807488.0000 - val_loss: 432995794944.0000
# Epoch 2/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 445650534400.0000 - val_loss: 428946915328.0000
# Epoch 3/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 429123731456.0000 - val_loss: 393050226688.0000
# Epoch 4/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 360252932096.0000 - val_loss: 271691022336.0000
# Epoch 5/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 219915501568.0000 - val_loss: 129747156992.0000
# Epoch 6/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 121467076608.0000 - val_loss: 104410906624.0000
# Epoch 7/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 99171041280.0000 - val_loss: 102536691712.0000
# Epoch 8/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 104167161856.0000 - val_loss: 100987961344.0000
# Epoch 9/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 92805709824.0000 - val_loss: 99159711744.0000
# Epoch 10/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 93920894976.0000 - val_loss: 97148960768.0000
# Epoch 11/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 96560562176.0000 - val_loss: 95045197824.0000
# Epoch 12/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 89184681984.0000 - val_loss: 92804792320.0000
# Epoch 13/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 81938989056.0000 - val_loss: 90457407488.0000
# Epoch 14/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 90466738176.0000 - val_loss: 88101044224.0000
# Epoch 15/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 86414647296.0000 - val_loss: 85502689280.0000
# Epoch 16/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 79851167744.0000 - val_loss: 82750554112.0000
# Epoch 17/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 77978845184.0000 - val_loss: 79933046784.0000
# Epoch 18/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 77963345920.0000 - val_loss: 77021569024.0000
# Epoch 19/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 72908685312.0000 - val_loss: 74033152000.0000
# Epoch 20/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 84375158784.0000 - val_loss: 71062773760.0000
# Epoch 21/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 71689428992.0000 - val_loss: 68069879808.0000
# Epoch 22/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 65425543168.0000 - val_loss: 65201971200.0000
# Epoch 23/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 64056590336.0000 - val_loss: 62722801664.0000
# Epoch 24/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 62780895232.0000 - val_loss: 60245143552.0000
# Epoch 25/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 61591109632.0000 - val_loss: 58218590208.0000
# Epoch 26/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 59080179712.0000 - val_loss: 56615886848.0000
# Epoch 27/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 55075733504.0000 - val_loss: 55160348672.0000
# Epoch 28/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 56535953408.0000 - val_loss: 53941182464.0000
# Epoch 29/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 52284223488.0000 - val_loss: 52989153280.0000
# Epoch 30/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49339625472.0000 - val_loss: 52169318400.0000
# Epoch 31/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 50225418240.0000 - val_loss: 51431895040.0000
# Epoch 32/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 50108346368.0000 - val_loss: 50777423872.0000
# Epoch 33/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48063119360.0000 - val_loss: 50297270272.0000
# Epoch 34/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47400615936.0000 - val_loss: 49697546240.0000
# Epoch 35/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49422442496.0000 - val_loss: 49225998336.0000
# Epoch 36/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46150320128.0000 - val_loss: 48743456768.0000
# Epoch 37/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 44550578176.0000 - val_loss: 48397889536.0000
# Epoch 38/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 45144293376.0000 - val_loss: 47911800832.0000
# Epoch 39/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 44610441216.0000 - val_loss: 47557832704.0000
# Epoch 40/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 49843027968.0000 - val_loss: 47064293376.0000
# Epoch 41/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 47807057920.0000 - val_loss: 46745464832.0000
# Epoch 42/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48207122432.0000 - val_loss: 46326157312.0000
# Epoch 43/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 45423386624.0000 - val_loss: 45968330752.0000
# Epoch 44/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 44144951296.0000 - val_loss: 45728391168.0000
# Epoch 45/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46159396864.0000 - val_loss: 45275021312.0000
# Epoch 46/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 45605335040.0000 - val_loss: 44944646144.0000
# Epoch 47/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43186692096.0000 - val_loss: 44567924736.0000
# Epoch 48/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46122127360.0000 - val_loss: 44234444800.0000
# Epoch 49/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43770085376.0000 - val_loss: 43843870720.0000
# Epoch 50/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 42645921792.0000 - val_loss: 43508662272.0000
# Epoch 51/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48247029760.0000 - val_loss: 43218337792.0000
# Epoch 52/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43780341760.0000 - val_loss: 42838470656.0000
# Epoch 53/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40596410368.0000 - val_loss: 42463019008.0000
# Epoch 54/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38593847296.0000 - val_loss: 42116521984.0000
# Epoch 55/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38356434944.0000 - val_loss: 41715445760.0000
# Epoch 56/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 41335091200.0000 - val_loss: 41394974720.0000
# Epoch 57/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40727359488.0000 - val_loss: 41070493696.0000
# Epoch 58/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 41960706048.0000 - val_loss: 40729862144.0000
# Epoch 59/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 42042023936.0000 - val_loss: 40403226624.0000
# Epoch 60/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37211045888.0000 - val_loss: 40068120576.0000
# Epoch 61/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40348884992.0000 - val_loss: 39764762624.0000
# Epoch 62/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40735567872.0000 - val_loss: 39552585728.0000
# Epoch 63/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 37252616192.0000 - val_loss: 39263014912.0000
# Epoch 64/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 
400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34506702848.0000 - val_loss: 33843335168.0000
# Epoch 114/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34498355200.0000 - val_loss: 33753212928.0000
# Epoch 115/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32218472448.0000 - val_loss: 33740929024.0000
# Epoch 116/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35556868096.0000 - val_loss: 33655519232.0000
# Epoch 117/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34328057856.0000 - val_loss: 33584439296.0000
# Epoch 118/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33444968448.0000 - val_loss: 33549684736.0000
# Epoch 119/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34908180480.0000 - val_loss: 33552381952.0000
# Epoch 120/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35353174016.0000 - val_loss: 33471186944.0000
# Epoch 121/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 38161952768.0000 - val_loss: 33386981376.0000
# Epoch 122/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34368536576.0000 - val_loss: 33337927680.0000
# Epoch 123/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31879884800.0000 - val_loss: 33312989184.0000
# Epoch 124/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33739573248.0000 - val_loss: 33240633344.0000
# Epoch 125/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35820642304.0000 - val_loss: 33216129024.0000
# Epoch 126/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34058164224.0000 - val_loss: 33139451904.0000
# Epoch 127/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32310245376.0000 - val_loss: 33102909440.0000
# Epoch 128/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33762396160.0000 - val_loss: 33080989696.0000
# Epoch 129/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34149257216.0000 - val_loss: 33015701504.0000
# Epoch 130/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33662566400.0000 - val_loss: 32988891136.0000
# Epoch 131/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32958488576.0000 - val_loss: 32953896960.0000
# Epoch 132/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34578739200.0000 - val_loss: 32861095936.0000
# Epoch 133/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36193214464.0000 - val_loss: 32796096512.0000
# Epoch 134/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32086839296.0000 - val_loss: 32841478144.0000
# Epoch 135/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32829474816.0000 - val_loss: 32722966528.0000
# Epoch 136/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31995852800.0000 - val_loss: 32760924160.0000
# Epoch 137/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32520790016.0000 - val_loss: 32635926528.0000
# Epoch 138/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31632371712.0000 - val_loss: 32591147008.0000
# Epoch 139/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32783808512.0000 - val_loss: 32552062976.0000
# Epoch 140/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33717704704.0000 - val_loss: 32612014080.0000
# Epoch 141/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35540807680.0000 - val_loss: 32491862016.0000
# Epoch 142/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32522043392.0000 - val_loss: 32462923776.0000
# Epoch 143/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32087121920.0000 - val_loss: 32418160640.0000
# Epoch 144/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33363249152.0000 - val_loss: 32360409088.0000
# Epoch 145/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32024233984.0000 - val_loss: 32330489856.0000
# Epoch 146/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32432513024.0000 - val_loss: 32362248192.0000
# Epoch 147/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32153724928.0000 - val_loss: 32287592448.0000
# Epoch 148/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32299134976.0000 - val_loss: 32291655680.0000
# Epoch 149/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32043304960.0000 - val_loss: 32186482688.0000
# Epoch 150/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31619868672.0000 - val_loss: 32285454336.0000
# Epoch 151/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32286095360.0000 - val_loss: 32119863296.0000
# Epoch 152/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33881243648.0000 - val_loss: 32114796544.0000
# Epoch 153/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31111884800.0000 - val_loss: 32055994368.0000
# Epoch 154/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34914775040.0000 - val_loss: 32058036224.0000
# Epoch 155/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31913164800.0000 - val_loss: 32007993344.0000
# Epoch 156/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34561961984.0000 - val_loss: 31955560448.0000
# Epoch 157/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32206985216.0000 - val_loss: 31933177856.0000
# Epoch 158/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31973304320.0000 - val_loss: 31894136832.0000
# Epoch 159/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31711158272.0000 - val_loss: 31867330560.0000
# Epoch 160/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31802875904.0000 - val_loss: 31849705472.0000
# Epoch 161/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32879081472.0000 - val_loss: 31857743872.0000
# Epoch 162/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34842898432.0000 - val_loss: 31894962176.0000
# Epoch 163/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30728284160.0000 - val_loss: 31852273664.0000
# Epoch 164/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32096690176.0000 - val_loss: 31704756224.0000
# Epoch 165/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34401787904.0000 - val_loss: 31673147392.0000
# Epoch 166/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31012497408.0000 - val_loss: 31642927104.0000
# Epoch 167/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31275407360.0000 - val_loss: 31668299776.0000
# Epoch 168/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31161296896.0000 - val_loss: 31593230336.0000
# Epoch 169/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33024958464.0000 - val_loss: 31576676352.0000
# Epoch 170/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31875061760.0000 - val_loss: 31543873536.0000
# Epoch 171/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32405762048.0000 - val_loss: 31527532544.0000
# Epoch 172/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 34948722688.0000 - val_loss: 31498170368.0000
# Epoch 173/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29598607360.0000 - val_loss: 31521679360.0000
# Epoch 174/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31708248064.0000 - val_loss: 31459024896.0000
# Epoch 175/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31071551488.0000 - val_loss: 31437115392.0000
# Epoch 176/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31886436352.0000 - val_loss: 31413979136.0000
# Epoch 177/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32219121664.0000 - val_loss: 31367118848.0000
# Epoch 178/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31813625856.0000 - val_loss: 31354798080.0000
# Epoch 179/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31500892160.0000 - val_loss: 31332954112.0000
# Epoch 180/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33090453504.0000 - val_loss: 31399047168.0000
# Epoch 181/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31411263488.0000 - val_loss: 31269234688.0000
# Epoch 182/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33657851904.0000 - val_loss: 31243495424.0000
# Epoch 183/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31175958528.0000 - val_loss: 31210678272.0000
# Epoch 184/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32259731456.0000 - val_loss: 31255107584.0000
# Epoch 185/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32601800704.0000 - val_loss: 31284742144.0000
# Epoch 186/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32537880576.0000 - val_loss: 31148593152.0000
# Epoch 187/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30926333952.0000 - val_loss: 31201159168.0000
# Epoch 188/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31431075840.0000 - val_loss: 31123533824.0000
# Epoch 189/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30523926528.0000 - val_loss: 31135156224.0000
# Epoch 190/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31403859968.0000 - val_loss: 31059259392.0000
# Epoch 191/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29585057792.0000 - val_loss: 31111243776.0000
# Epoch 192/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32202545152.0000 - val_loss: 31130333184.0000
# Epoch 193/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31522064384.0000 - val_loss: 31176122368.0000
# Epoch 194/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31829798912.0000 - val_loss: 31064010752.0000
# Epoch 195/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32011636736.0000 - val_loss: 30947516416.0000
# Epoch 196/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30599270400.0000 - val_loss: 30927699968.0000
# Epoch 197/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30877825024.0000 - val_loss: 30913595392.0000
# Epoch 198/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31252652032.0000 - val_loss: 30918240256.0000
# Epoch 199/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30929735680.0000 - val_loss: 30946490368.0000
# Epoch 200/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30552979456.0000 - val_loss: 30920183808.0000
# Epoch 201/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29601400832.0000 - val_loss: 30871779328.0000
# Epoch 202/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31200063488.0000 - val_loss: 30836436992.0000
# Epoch 203/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31103531008.0000 - val_loss: 30788833280.0000
# Epoch 204/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32577437696.0000 - val_loss: 30879844352.0000
# Epoch 205/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32467374080.0000 - val_loss: 30732371968.0000
# Epoch 206/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30722060288.0000 - val_loss: 30756868096.0000
# Epoch 207/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31059390464.0000 - val_loss: 30709790720.0000
# Epoch 208/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32703229952.0000 - val_loss: 30691012608.0000
# Epoch 209/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32036159488.0000 - val_loss: 30662760448.0000
# Epoch 210/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30312398848.0000 - val_loss: 30691442688.0000
# Epoch 211/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31232610304.0000 - val_loss: 30651414528.0000
# Epoch 212/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32407527424.0000 - val_loss: 30726176768.0000
# Epoch 213/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29394812928.0000 - val_loss: 30578167808.0000
# Epoch 214/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29715748864.0000 - val_loss: 30587299840.0000
# Epoch 215/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29328076800.0000 - val_loss: 30532704256.0000
# Epoch 216/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32462102528.0000 - val_loss: 30497550336.0000
# Epoch 217/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29993265152.0000 - val_loss: 30467577856.0000
# Epoch 218/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31299256320.0000 - val_loss: 30464186368.0000
# Epoch 219/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32588601344.0000 - val_loss: 30439557120.0000
# Epoch 220/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33527508992.0000 - val_loss: 30454239232.0000
# Epoch 221/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30213611520.0000 - val_loss: 30415347712.0000
# Epoch 222/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32953184256.0000 - val_loss: 30370134016.0000
# Epoch 223/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31227289600.0000 - val_loss: 30337853440.0000
# Epoch 224/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29463937024.0000 - val_loss: 30322221056.0000
# Epoch 225/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31907385344.0000 - val_loss: 30313695232.0000
# Epoch 226/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29091672064.0000 - val_loss: 30307921920.0000
# Epoch 227/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33643808768.0000 - val_loss: 30244491264.0000
# Epoch 228/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30844821504.0000 - val_loss: 30208159744.0000
# Epoch 229/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29632206848.0000 - val_loss: 30197809152.0000
# Epoch 230/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29748248576.0000 - val_loss: 30175807488.0000
# Epoch 231/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29727700992.0000 - val_loss: 30126958592.0000
# Epoch 232/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31597109248.0000 - val_loss: 30140143616.0000
# Epoch 233/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31255318528.0000 - val_loss: 30147246080.0000
# Epoch 234/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28565458944.0000 - val_loss: 30112980992.0000
# Epoch 235/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31963492352.0000 - val_loss: 30028722176.0000
# Epoch 236/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29608409088.0000 - val_loss: 30063945728.0000
# Epoch 237/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29145139200.0000 - val_loss: 29983752192.0000
# Epoch 238/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30343360512.0000 - val_loss: 29915043840.0000
# Epoch 239/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29829677056.0000 - val_loss: 29904162816.0000
# Epoch 240/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29765226496.0000 - val_loss: 30130354176.0000
# Epoch 241/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30226892800.0000 - val_loss: 29794519040.0000
# Epoch 242/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28986146816.0000 - val_loss: 29819117568.0000
# Epoch 243/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29777797120.0000 - val_loss: 29762680832.0000
# Epoch 244/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29395767296.0000 - val_loss: 29714857984.0000
# Epoch 245/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29385048064.0000 - val_loss: 29687826432.0000
# Epoch 246/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29339353088.0000 - val_loss: 29594673152.0000
# Epoch 247/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31400992768.0000 - val_loss: 29559783424.0000
# Epoch 248/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28825389056.0000 - val_loss: 29626832896.0000
# Epoch 249/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28725665792.0000 - val_loss: 29556123648.0000
# Epoch 250/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30375583744.0000 - val_loss: 29473277952.0000
# Epoch 251/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30743988224.0000 - val_loss: 29444052992.0000
# Epoch 252/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29985134592.0000 - val_loss: 29403553792.0000
# Epoch 253/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29387567104.0000 - val_loss: 29448638464.0000
# Epoch 254/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29573462016.0000 - val_loss: 29347405824.0000
# Epoch 255/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29870534656.0000 - val_loss: 29378695168.0000
# Epoch 256/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30789814272.0000 - val_loss: 29318930432.0000
# Epoch 257/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31140597760.0000 - val_loss: 29260519424.0000
# Epoch 258/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 32080324608.0000 - val_loss: 29249415168.0000
# Epoch 259/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30956722176.0000 - val_loss: 29257625600.0000
# Epoch 260/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30919313408.0000 - val_loss: 29183221760.0000
# Epoch 261/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28467976192.0000 - val_loss: 29120421888.0000
# Epoch 262/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28793563136.0000 - val_loss: 29178060800.0000
# Epoch 263/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28162504704.0000 - val_loss: 29079859200.0000
# Epoch 264/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29413001216.0000 - val_loss: 29027149824.0000
# Epoch 265/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29965615104.0000 - val_loss: 29020467200.0000
# Epoch 266/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28508659712.0000 - val_loss: 29003102208.0000
# Epoch 267/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29008142336.0000 - val_loss: 28964759552.0000
# Epoch 268/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27229632512.0000 - val_loss: 29008199680.0000
# Epoch 269/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29782874112.0000 - val_loss: 29003622400.0000
# Epoch 270/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30085351424.0000 - val_loss: 28976941056.0000
# Epoch 271/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29685841920.0000 - val_loss: 28900245504.0000
# Epoch 272/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29636034560.0000 - val_loss: 28885020672.0000
# Epoch 273/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31106623488.0000 - val_loss: 28866711552.0000
# Epoch 274/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27890085888.0000 - val_loss: 28818083840.0000
# Epoch 275/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29758439424.0000 - val_loss: 28784881664.0000
# Epoch 276/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28419381248.0000 - val_loss: 28753768448.0000
# Epoch 277/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28201826304.0000 - val_loss: 28792018944.0000
# Epoch 278/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29030197248.0000 - val_loss: 28709124096.0000
# Epoch 279/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30059681792.0000 - val_loss: 28693716992.0000
# Epoch 280/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29597415424.0000 - val_loss: 28799901696.0000
# Epoch 281/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27947286528.0000 - val_loss: 28621586432.0000
# Epoch 282/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29969299456.0000 - val_loss: 28637722624.0000
# Epoch 283/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27528153088.0000 - val_loss: 28615518208.0000
# Epoch 284/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28453648384.0000 - val_loss: 28566560768.0000
# Epoch 285/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28564109312.0000 - val_loss: 28799684608.0000
# Epoch 286/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29253466112.0000 - val_loss: 28532103168.0000
# Epoch 287/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28343074816.0000 - val_loss: 28525754368.0000
# Epoch 288/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27941656576.0000 - val_loss: 28512270336.0000
# Epoch 289/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29424863232.0000 - val_loss: 28576473088.0000
# Epoch 290/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29573562368.0000 - val_loss: 28417243136.0000
# Epoch 291/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29487695872.0000 - val_loss: 28386723840.0000
# Epoch 292/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27646867456.0000 - val_loss: 28381433856.0000
# Epoch 293/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29115125760.0000 - val_loss: 28351406080.0000
# Epoch 294/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28789233664.0000 - val_loss: 28319428608.0000
# Epoch 295/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28433029120.0000 - val_loss: 28294895616.0000
# Epoch 296/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27967430656.0000 - val_loss: 28315441152.0000
# Epoch 297/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28423290880.0000 - val_loss: 28246745088.0000
# Epoch 298/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29373886464.0000 - val_loss: 28285960192.0000
# Epoch 299/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29534416896.0000 - val_loss: 28208558080.0000
# Epoch 300/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28833652736.0000 - val_loss: 28187222016.0000
# Epoch 301/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27613067264.0000 - val_loss: 28155891712.0000
# Epoch 302/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28384028672.0000 - val_loss: 28261851136.0000
# Epoch 303/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30066139136.0000 - val_loss: 28134438912.0000
# Epoch 304/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28449120256.0000 - val_loss: 28090689536.0000
# Epoch 305/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29328865280.0000 - val_loss: 28068249600.0000
# Epoch 306/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29283325952.0000 - val_loss: 28077537280.0000
# Epoch 307/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28794542080.0000 - val_loss: 27994898432.0000
# Epoch 308/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28719865856.0000 - val_loss: 27993401344.0000
# Epoch 309/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27504498688.0000 - val_loss: 28074663936.0000
# Epoch 310/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28170590208.0000 - val_loss: 27976820736.0000
# Epoch 311/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28082038784.0000 - val_loss: 27888662528.0000
# Epoch 312/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26487887872.0000 - val_loss: 27896952832.0000
# Epoch 313/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27971362816.0000 - val_loss: 27994474496.0000
# Epoch 314/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28949499904.0000 - val_loss: 27870547968.0000
# Epoch 315/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28749998080.0000 - val_loss: 27828879360.0000
# Epoch 316/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26941347840.0000 - val_loss: 27862151168.0000
# Epoch 317/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28088938496.0000 - val_loss: 27925987328.0000
# Epoch 318/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26849511424.0000 - val_loss: 27729573888.0000
# Epoch 319/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28711917568.0000 - val_loss: 27671648256.0000
# Epoch 320/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29416355840.0000 - val_loss: 27683262464.0000
# Epoch 321/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27099539456.0000 - val_loss: 27735742464.0000
# Epoch 322/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26995466240.0000 - val_loss: 27609741312.0000
# Epoch 323/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28473563136.0000 - val_loss: 27582205952.0000
# Epoch 324/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27738966016.0000 - val_loss: 27551907840.0000
# Epoch 325/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27594207232.0000 - val_loss: 27530625024.0000
# Epoch 326/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28137748480.0000 - val_loss: 27634307072.0000
# Epoch 327/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26264332288.0000 - val_loss: 27584751616.0000
# Epoch 328/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28142680064.0000 - val_loss: 27541983232.0000
# Epoch 329/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27589793792.0000 - val_loss: 27487401984.0000
# Epoch 330/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27852861440.0000 - val_loss: 27407525888.0000
# Epoch 331/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27696115712.0000 - val_loss: 27438315520.0000
# Epoch 332/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28015962112.0000 - val_loss: 27375796224.0000
# Epoch 333/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31105490944.0000 - val_loss: 27357202432.0000
# Epoch 334/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26442221568.0000 - val_loss: 27286138880.0000
# Epoch 335/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28380459008.0000 - val_loss: 27308451840.0000
# Epoch 336/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26381340672.0000 - val_loss: 27351721984.0000
# Epoch 337/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27386886144.0000 - val_loss: 27218548736.0000
# Epoch 338/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29057359872.0000 - val_loss: 27179415552.0000
# Epoch 339/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25520979968.0000 - val_loss: 27253039104.0000
# Epoch 340/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27802218496.0000 - val_loss: 27183896576.0000
# Epoch 341/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26258946048.0000 - val_loss: 27301261312.0000
# Epoch 342/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28635383808.0000 - val_loss: 27050954752.0000
# Epoch 343/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26506031104.0000 - val_loss: 27099695104.0000
# Epoch 344/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27809888256.0000 - val_loss: 27031996416.0000
# Epoch 345/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27151644672.0000 - val_loss: 26970388480.0000
# Epoch 346/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26268637184.0000 - val_loss: 26986014720.0000
# Epoch 347/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25973557248.0000 - val_loss: 26905565184.0000
# Epoch 348/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28221861888.0000 - val_loss: 26968199168.0000
# Epoch 349/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27260958720.0000 - val_loss: 26810316800.0000
# Epoch 350/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27854002176.0000 - val_loss: 26923954176.0000
# Epoch 351/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27184791552.0000 - val_loss: 26749204480.0000
# Epoch 352/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27328989184.0000 - val_loss: 26777909248.0000
# Epoch 353/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26997661696.0000 - val_loss: 26724177920.0000
# Epoch 354/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28069197824.0000 - val_loss: 26656159744.0000
# Epoch 355/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27341619200.0000 - val_loss: 26736459776.0000
# Epoch 356/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26702368768.0000 - val_loss: 26597799936.0000
# Epoch 357/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27141490688.0000 - val_loss: 26560452608.0000
# Epoch 358/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26690531328.0000 - val_loss: 26693396480.0000
# Epoch 359/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25738434560.0000 - val_loss: 26490552320.0000
# Epoch 360/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26707965952.0000 - val_loss: 26470672384.0000
# Epoch 361/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26276100096.0000 - val_loss: 26485565440.0000
# Epoch 362/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27747657728.0000 - val_loss: 26372055040.0000
# Epoch 363/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26902863872.0000 - val_loss: 26362841088.0000
# Epoch 364/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27555024896.0000 - val_loss: 26360965120.0000
# Epoch 365/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25580097536.0000 - val_loss: 26404597760.0000
# Epoch 366/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27902076928.0000 - val_loss: 26394574848.0000
# Epoch 367/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24946593792.0000 - val_loss: 26272002048.0000
# Epoch 368/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27466383360.0000 - val_loss: 26234015744.0000
# Epoch 369/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27307626496.0000 - val_loss: 26144813056.0000
# Epoch 370/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27261573120.0000 - val_loss: 26166349824.0000
# Epoch 371/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24587669504.0000 - val_loss: 26145818624.0000
# Epoch 372/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25429106688.0000 - val_loss: 26148528128.0000
# Epoch 373/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27845957632.0000 - val_loss: 26212581376.0000
# Epoch 374/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26839355392.0000 - val_loss: 26028222464.0000
# Epoch 375/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26889510912.0000 - val_loss: 25926043648.0000
# Epoch 376/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25194174464.0000 - val_loss: 25975599104.0000
# Epoch 377/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26217418752.0000 - val_loss: 25857019904.0000
# Epoch 378/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25935327232.0000 - val_loss: 25813739520.0000
# Epoch 379/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27707889664.0000 - val_loss: 25854896128.0000
# Epoch 380/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26531465216.0000 - val_loss: 25723938816.0000
# Epoch 381/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27270950912.0000 - val_loss: 25718480896.0000
# Epoch 382/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 24638726144.0000 - val_loss: 25669257216.0000
# Epoch 383/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26208833536.0000 - val_loss: 25614977024.0000
# Epoch 384/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27443636224.0000 - val_loss: 25573302272.0000
# Epoch 385/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26345226240.0000 - val_loss: 25531975680.0000
# Epoch 386/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25537568768.0000 - val_loss: 25469091840.0000
# Epoch 387/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25040873472.0000 - val_loss: 25444294656.0000
# Epoch 388/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26509719552.0000 - val_loss: 25464729600.0000
# Epoch 389/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25428615168.0000 - val_loss: 25409880064.0000
# Epoch 390/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26178314240.0000 - val_loss: 25355085824.0000
# Epoch 391/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25770319872.0000 - val_loss: 25285820416.0000
# Epoch 392/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25039876096.0000 - val_loss: 25278281728.0000
# Epoch 393/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26176892928.0000 - val_loss: 25327960064.0000
# Epoch 394/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26446379008.0000 - val_loss: 25157085184.0000
# Epoch 395/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25368860672.0000 - val_loss: 25128273920.0000
# Epoch 396/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25282453504.0000 - val_loss: 25178669056.0000
# Epoch 397/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26051147776.0000 - val_loss: 25064906752.0000
# Epoch 398/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25744408576.0000 - val_loss: 25046824960.0000
# Epoch 399/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25618853888.0000 - val_loss: 25054875648.0000
# Epoch 400/400
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26349064192.0000 - val_loss: 24948207616.0000

# %% [markdown]
# __Training loss per epoch__
#
# This plot shows the training loss per epoch.
# This plot helps us to see if there is overfitting in the model. In this case there is no overfitting because both lines go down at the same time.

# %%
losses = pd.DataFrame(model.history.history)

plt.figure(figsize=(15,5))
sns.lineplot(data=losses,lw=3)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss per Epoch')
sns.despine()

# %% [markdown]
# __Regression Evaluation Metrics__
#
# Mean Absolute Error (MAE) is the mean of the absolute value of the errors:
#
# n∑i=1/n|yi−y^i|
#
# Mean Squared Error (MSE) is the mean of the squared errors:
#
# n∑i=1/n(yi−y^i)2
#
# Root Mean Squared Error (RMSE) is the square root of the mean of the squared errors:
#
# n∑i=1 √1/n(yi−y^i)2
#
#
# __Comparing these metrics__
#
# MAE is the easiest to understand, because it's the average error.
# MSE is more popular than MAE, because MSE "punishes" larger errors, which tends to be useful in the real world.
# RMSE is even more popular than MSE, because RMSE is interpretable in the "y" units.

# %% [markdown]
# __Prediction (What we do on brand new data)__
#
# In this part we are giving the model the test set to get a list of predictions. Then we compare the correct values with the list of predictions. We use different metrics to compare the predictions, in this case we use MAE, MSE, RMSE and Variance Regression Score.
#
# Let us start by analyzing the MAE, which is 103,500. This means that our model is off on average about `$100,000`.
#
# Is that MAE good or bad?
#
# For that we must take into account our original data set and see what kind of values we have. For instance, the mean is 540,000, therefore the MEA is about 19% of the mean price. This is not a particularly good result.
#
# To better understand this error, we can use the variance regression score, where the best possible score is 1.0 and lower values are worse. This tells you how much variance is being explain by your model. In our case we have 0.80 which is a normal result.

# %%
# evaluation on test data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

# %%
# predictions on the test set
predictions = model.predict(X_valid)

print('MAE: ', mean_absolute_error(y_valid,predictions))
print('MSE: ', mean_squared_error(y_valid,predictions))
print('RMSE: ', np.sqrt(mean_squared_error(y_valid,predictions)))
print('Variance Regression Score: ', explained_variance_score(y_valid,predictions))

print('\n\nDescriptive Statistics:\n',housePrices['price'].describe())
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step
# MAE:  96894.90681629781
# MSE:  24948203291.020638
# RMSE:  157950.00250402227
# Variance Regression Score:  0.8221739730283423
#
#
# Descriptive Statistics:
#  count    2.161300e+04
# mean     5.400881e+05
# std      3.671272e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %% [markdown]
# __Model predictions vs perfect fit__
#
# We can compare the model predictions with a perfect fit to see how accurate the model is.
#
# The red line represents the perfect prediction.
#
# We are being punish by the outliers, which are the expensive houses. Our model is not good predicting luxury houses.
#
# On the other hand, our model is good predicting the price of houses between 0 and $2 million. There is clearly a good fit.
#
# It may be worth it retraining our model just on price houses below $3 million.  df[df['price'] <= 3000000]

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))

# Our model predictions
plt.scatter(y_valid,predictions)

# Perfect predictions
plt.plot(y_valid,y_valid,'r')

errors = y_valid.values.reshape(6484, 1) - predictions
sns.histplot(errors, ax=axes[0])

sns.despine(left=True, bottom=True)
axes[0].set(xlabel='Error', ylabel='', title='Error Histogram')
axes[1].set(xlabel='Test True Y', ylabel='Model Predictions', title='Model Predictions vs Perfect Fit')
# Out:
# [Text(0.5, 0, 'Test True Y'),
#  Text(0, 0.5, 'Model Predictions'),
#  Text(0.5, 1.0, 'Model Predictions vs Perfect Fit')]

# %% [markdown]
# __Predicting a new comer house__
#
# We are going to use the model to predict the price on a brand-new house. We are going to choose the first house of the data set and drop the price. single_house is going to have all the features that we need to predict the price. After that we need to reshape the variable and scale the features.
#
# The original price is 221,900 and the model prediction is ~ $285,000.

# %%
# features of new house
single_house = housePrices.drop('price',axis=1).iloc[0]
print(f'Features of new house:\n {single_house}')

# reshape the numpy array and scale the features
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# run the model and get the price prediction
print('\nPrediction Price:', model.predict(single_house)[0,0])

# original price
print('\nOriginal Price:', housePrices.iloc[0]['price'])
# Out:
# Features of new house:
#  bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# month              10.0000
# year             2014.0000
# Name: 0, dtype: float64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# Prediction Price: 293115.62
#
# Original Price: 221900.0
# c:\Users\ASUS\miniconda3\envs\env_deep\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Go ahead and create a model for houses with a less skewed distribution

# %%
housePrices2 = housePrices[housePrices['price'] <= 3000000]
housePrices2.head(10)
# Out:
#            id    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520   221900         3       1.00         1180      5650     1.0
# 1  6414100192   538000         3       2.25         2570      7242     2.0
# 2  5631500400   180000         2       1.00          770     10000     1.0
# 3  2487200875   604000         4       3.00         1960      5000     1.0
# 4  1954400510   510000         3       2.00         1680      8080     1.0
# 5  7237550310  1225000         4       4.50         5420    101930     1.0
# 6  1321400060   257500         3       2.25         1715      6819     2.0
# 7  2008000270   291850         3       1.50         1060      9711     1.0
# 8  2414600126   229500         3       1.00         1780      7470     1.0
# 9  3793500160   323000         3       2.50         1890      6560     2.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
# 5           0     0          3  ...           1530      2001             0
# 6           0     0          3  ...              0      1995             0
# 7           0     0          3  ...              0      1963             0
# 8           0     0          3  ...            730      1960             0
# 9           0     0          3  ...              0      2003             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  month  year
# 0    98178  47.5112 -122.257           1340        5650     10  2014
# 1    98125  47.7210 -122.319           1690        7639     12  2014
# 2    98028  47.7379 -122.233           2720        8062      2  2015
# 3    98136  47.5208 -122.393           1360        5000     12  2014
# 4    98074  47.6168 -122.045           1800        7503      2  2015
# 5    98053  47.6561 -122.005           4760      101930      5  2014
# 6    98003  47.3097 -122.327           2238        6819      6  2014
# 7    98198  47.4095 -122.315           1650        9711      1  2015
# 8    98146  47.5123 -122.337           1780        8113      4  2015
# 9    98038  47.3684 -122.031           2390        7570      3  2015
#
# [10 rows x 22 columns]

# %%
'''
WARNING:

Para el workshop en el punto de las casas es  POR DEBAJO DE 3000000, el profesor dijo que se habia equivocado pero no se corrigio en el word



'''
